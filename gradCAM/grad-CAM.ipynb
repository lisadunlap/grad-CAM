# %% [markdown]
# # Grad-CAM

# %%
import numpy as np
import argparse
import matplotlib.pyplot as plt
from torchvision import models, transforms
from grad_cam import GradCAM
from grad_cam import get_gradCAM_img
from skimage import io

# %%
#get heatmap of image using gradcam given an image path, model name, number of categories, 
#and an alternate layer (optional; otherwise will just use the last conv layer)
get_gradCAM_img('samples/cat_dog.png', 'resnet18', 3)
# Out:
# [0.42589] boxer
# [0.26502] bull_mastiff
# [0.17546] tiger_cat

# %%
get_gradCAM_img('samples/cat_dog.png', 'resnet18', 3, 'layer3')
# Out:
# [0.42589] boxer
# [0.26502] bull_mastiff
# [0.17546] tiger_cat

# %%
get_gradCAM_img('samples/fruit.jpg', 'resnet18', 3)
# Out:
# [0.34032] ice_cream
# [0.19536] cup
# [0.12875] pineapple

# %%
get_gradCAM_img('samples/elephants.jpeg', 'resnet18', 3)
# Out:
# [0.63651] Indian_elephant
# [0.20014] tusker
# [0.16331] African_elephant

# %%
get_gradCAM_img('samples/night_trees.jpg', 'resnet18', 3)
# Out:
# [0.09004] fountain
# [0.07728] volcano
# [0.07476] lakeside

# %%
get_gradCAM_img('samples/milky_way_lions.jpg', 'resnet18', 3)
# Out:
# [0.15220] cheetah
# [0.10828] coyote
# [0.09383] wood_rabbit

# %%
get_gradCAM_img('samples/lion.jpg', 'resnet18', 3)
# Out:
# [0.67494] lion
# [0.09715] Arabian_camel
# [0.07896] ostrich
